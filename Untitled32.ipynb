# %%
import numpy as np
import pandas as pd
var = pd.read_csv(r'C:\Users\DELL\Downloads\nyc_taxis.csv')
var
# Out:
#        pickup_year  pickup_month  pickup_day  pickup_dayofweek  pickup_time  \
# 0             2016             1           1                 5            0
# 1             2016             1           1                 5            0
# 2             2016             1           1                 5            0
# 3             2016             1           1                 5            0
# 4             2016             1           1                 5            0
# ...            ...           ...         ...               ...          ...
# 89555         2016             6          30                 4            5
# 89556         2016             6          30                 4            5
# 89557         2016             6          30                 4            5
# 89558         2016             6          30                 4            5
# 89559         2016             6          30                 4            5
#
# ...

# %%
var.head()
# Out:
#    pickup_year  pickup_month  pickup_day  pickup_dayofweek  pickup_time  \
# 0         2016             1           1                 5            0
# 1         2016             1           1                 5            0
# 2         2016             1           1                 5            0
# 3         2016             1           1                 5            0
# 4         2016             1           1                 5            0
#
#    pickup_location_code  dropoff_location_code  trip_distance  trip_length  \
# 0                     2                      4          21.00         2037
# 1                     2                      1          16.29         1520
# 2                     2                      6          12.70         1462
# 3                     2                      6           8.70         1210
# 4                     2                      6           5.56          759
#
#    fare_amount  fees_amount  tolls_amount  tip_amount  total_amount  \
# ...

# %%
var.shape
# Out:
# (89560, 15)

# %%
var.shape[0]
# Out:
# 89560

# %%
var.shape[1]
# Out:
# 15

# %%
var.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89560 entries, 0 to 89559
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   pickup_year            89560 non-null  int64
#  1   pickup_month           89560 non-null  int64
#  2   pickup_day             89560 non-null  int64
#  3   pickup_dayofweek       89560 non-null  int64
#  4   pickup_time            89560 non-null  int64
#  5   pickup_location_code   89560 non-null  int64
#  6   dropoff_location_code  89560 non-null  int64
#  7   trip_distance          89560 non-null  float64
#  8   trip_length            89560 non-null  int64
#  9   fare_amount            89560 non-null  float64
#  10  fees_amount            89560 non-null  float64
#  11  tolls_amount           89560 non-null  float64
#  12  tip_amount             89560 non-null  float64
#  13  total_amount           89560 non-null  float64
# ...

# %%
var.describe()
# Out:
#        pickup_year  pickup_month    pickup_day  pickup_dayofweek  \
# count      89560.0  89560.000000  89560.000000      89560.000000
# mean        2016.0      3.614471     15.693535          3.841335
# std            0.0      1.692354      8.694046          2.001929
# min         2016.0      1.000000      1.000000          1.000000
# 25%         2016.0      2.000000      8.000000          2.000000
# 50%         2016.0      4.000000     16.000000          4.000000
# 75%         2016.0      5.000000     23.000000          5.000000
# max         2016.0      6.000000     31.000000          7.000000
#
#         pickup_time  pickup_location_code  dropoff_location_code  \
# count  89560.000000          89560.000000           89560.000000
# mean       3.082671              2.959882               3.379243
# std        1.404460              0.823339               1.382522
# min        0.000000              0.000000               0.000000
# ...

# %%
var.isnull()
# Out:
#        pickup_year  pickup_month  pickup_day  pickup_dayofweek  pickup_time  \
# 0            False         False       False             False        False
# 1            False         False       False             False        False
# 2            False         False       False             False        False
# 3            False         False       False             False        False
# 4            False         False       False             False        False
# ...            ...           ...         ...               ...          ...
# 89555        False         False       False             False        False
# 89556        False         False       False             False        False
# 89557        False         False       False             False        False
# 89558        False         False       False             False        False
# 89559        False         False       False             False        False
#
# ...

# %%
var.isnull().sum()
# Out:
# pickup_year              0
# pickup_month             0
# pickup_day               0
# pickup_dayofweek         0
# pickup_time              0
# pickup_location_code     0
# dropoff_location_code    0
# trip_distance            0
# trip_length              0
# fare_amount              0
# fees_amount              0
# tolls_amount             0
# tip_amount               0
# total_amount             0
# payment_type             0
# dtype: int64

# %%
import os
print(os.getcwd())  # This will print the current working directory
# Out:
# C:\Users\DELL

# %%
import numpy as np

x = [4, 4, 6, 9, 0]

y = np.array(x)

print(y)
# Out:
# [4 4 6 9 0]

# %%
import numpy as np

x = [4, 4, 6, 9, 0]

y = np.array(x)

print(y)
print(type(y))
# Out:
# [4 4 6 9 0]
# <class 'numpy.ndarray'>

# %%
l = []

for i in range(1,10):
    int_1 = int(input('enter you numbers :'))
    l.append(int_1)
    
print(np.array(l))
# Out:
# enter you numbers :3
# enter you numbers :30
# enter you numbers :60
# enter you numbers :100
# enter you numbers :1000
# enter you numbers :10000
# enter you numbers :1000
# enter you numbers :9567
# enter you numbers :0192837465
# [        3        30        60       100      1000     10000      1000
#       9567 192837465]

# %% [markdown]
# # 6-D Array

# %%
a = [3,2,6,8]
b = np.array([a])
print(b)
# Out:
# [[3 2 6 8]]

# %%
a = [3,2,6,8]
b = np.array([[[[[a]]]]])
print(b)
print(type(b))
# Out:
# [[[[[[3 2 6 8]]]]]]
# <class 'numpy.ndarray'>

# %%
a = [3,2,6,8]
b = np.array([[[[[a]]]]])
print(b)
print(type(b))
print(b.ndim)
# Out:
# [[[[[[3 2 6 8]]]]]]
# <class 'numpy.ndarray'>
# 6

# %% [markdown]
# # 20-D Array

# %%
c = [43, 56, 86]
d = np.array([[[[[[[[[[[[[[[[[[[[c]]]]]]]]]]]]]]]]]]]])
print(d)
# Out:
# [[[[[[[[[[[[[[[[[[[[[43 56 86]]]]]]]]]]]]]]]]]]]]]

# %%
c = [43, 56, 86]
d = np.array([[[[[[[[[[[[[[[[[[[[c]]]]]]]]]]]]]]]]]]]])
print(d)
print(type(d))
# Out:
# [[[[[[[[[[[[[[[[[[[[[43 56 86]]]]]]]]]]]]]]]]]]]]]
# <class 'numpy.ndarray'>

# %%
c = [43, 56, 86]
d = np.array([[[[[[[[[[[[[[[[[[[c]]]]]]]]]]]]]]]]]]])
print(d)
print(type(d))
print(d.ndim)
# Out:
# [[[[[[[[[[[[[[[[[[[[43 56 86]]]]]]]]]]]]]]]]]]]]
# <class 'numpy.ndarray'>
# 20

# %% [markdown]
# # 12-D Array

# %%
e = [34, 678, 80, 66, 98]
f = np.array(e,ndmin=12)
print(f)
# Out:
# [[[[[[[[[[[[ 34 678  80  66  98]]]]]]]]]]]]

# %%
e = [34, 678, 80, 66, 98]
f = np.array(e,ndmin=12)
print(f)
print(type(f))
# Out:
# [[[[[[[[[[[[ 34 678  80  66  98]]]]]]]]]]]]
# <class 'numpy.ndarray'>

# %%
e = [34, 678, 80, 66, 98]
f = np.array(e,ndmin=12)
print(f)
print(type(f))
print(f.ndim)
# Out:
# [[[[[[[[[[[[ 34 678  80  66  98]]]]]]]]]]]]
# <class 'numpy.ndarray'>
# 12
